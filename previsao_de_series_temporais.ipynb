# %% [markdown]
# <a href="https://colab.research.google.com/github/renatocorreia-rmcm/previsao-de-series-temporais/blob/main/previsao_de_series_temporais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Hello world"
# Out:
# 'Hello world'
